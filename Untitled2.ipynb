# %% [markdown]
# <a href="https://colab.research.google.com/github/prince2004coder/vmc-classes/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range (0,11,2):
  print(i)

# %%
# @title Default title text
lst = [1, 2, 3,'kiwi', 'c', [2, 3]]
print(lst)


#append. only add single elemnt if we try add more they add list not siongle element

lst.append([2, 3, 4 ])
print(lst)

#extend() add elemntsd of list we add
lst.extend([2, 3, 4])
print(lst)

#insert

lst.insert(2, "value")
print(lst)



#pop
lst.pop()
print(lst)

#remove

lst.remove(2)
print(lst)

#index
lst.index(2)
print(lst.index(2))

#count()

lst.count(3)
print(lst.count(3))

#sort

lst.sort()
print(lst)


#sum,min,max,sorted
# Out:
# [1, 2, 3, 'kiwi', 'c', [2, 3]]
# [1, 2, 3, 'kiwi', 'c', [2, 3], [2, 3, 4]]
# [1, 2, 3, 'kiwi', 'c', [2, 3], [2, 3, 4], 2, 3, 4]
# [1, 2, 'value', 3, 'kiwi', 'c', [2, 3], [2, 3, 4], 2, 3, 4]
# [1, 2, 'value', 3, 'kiwi', 'c', [2, 3], [2, 3, 4], 2, 3]
# [1, 'value', 3, 'kiwi', 'c', [2, 3], [2, 3, 4], 2, 3]
# 7
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1770/3678611481.py in <cell line: 0>()
#      40 #sort
#      41
# ---> 42 lst.sort()
#      43 print(lst)
#      44
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
lst = [1, 2, 3, 4, -1, 0, -4]
lst.sort()
print(lst)
# Out:
# [-4, -1, 0, 1, 2, 3, 4]

# %%
lst = [1, 2, 3, 4, -1, 0, -4, 5, 6]

sum(lst)
print(sum(lst))



print(min(lst))
print(max(lst))
print(sorted(lst))
# Out:
# 16
# -4
# 6
# [-4, -1, 0, 1, 2, 3, 4, 5, 6]

# %%
lst = [1, 2, 3, 4, -1, 0, -4, 5, 6]

a= sorted(lst)
print(lst)
# Out:
# [1, 2, 3, 4, -1, 0, -4, 5, 6]

# %%
#touples fubnction


#category                functions
#count values.           count ()
#find                    index ()
#size.                   len ()
#total                   sum ()
#highest/lowwest.        max()/min()
# sort                   sorted () (returns list)

# %%
tp= (1, 2, 3, 4, 5 ,6)
print(tp.count(2))


print( tp.index(4))

print(len(tp))


print(sum(tp))


print(max(tp))
print(min(tp))


print(sorted(tp))
# Out:
# 1
# 3
# 6
# 21
# 6
# 1
# [1, 2, 3, 4, 5, 6]

# %%
lst1 = [1,2,3,4,5,6]
lst2 = [8,9,7,6,5,4]

result =[]
for i in range (len(lst1)):
    result.append(lst1[i] + lst2[i])
print(result)
# Out:
# [9, 11, 10, 10, 10, 10]
